# %%
#!pip install transformers accelerate
# !pip install vllm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 MB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 26.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 58.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 MB 9.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 MB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 17.2 MB/s eta 0:00:00
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
from vllm import LLM, SamplingParams
import os
sampling_params = SamplingParams(temperature=0.8, top_p=0.95,max_tokens=1500)

# %%
llm = LLM(model="microsoft/Phi-3-mini-4k-instruct",dtype="half")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/904 [00:00<?, ?B/s]
# WARNING 05-29 13:57:05 config.py:1086] Casting torch.bfloat16 to torch.float16.
# ...

# %%
prompt = "AI is future"
output = llm.generate(prompt, sampling_params=sampling_params)
print(output)
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:51<00:00, 51.94s/it]
# ...

# %%
for outputs in output:
    prompt = outputs.prompt
    generated_text = outputs.outputs[0].text
    #print(f"Prompt: {prompt!r}, Generated text: {generated_text!r}")
print(generated_text)
# Out:
#  perfect tense, used to indicate that an action will have been completed by a specific point in the future. For example, "By next year, I will have graduated from college."
#
# In the given sentence, "I will have made my decision by tomorrow evening," the speaker is expressing that their decision-making process will be completed by tomorrow evening. It is a future perfect tense statement, indicating that the action (making the decision) will be finished by a specific time in the future (tomorrow evening).
#
# So, the sentence "I will have made my decision by tomorrow evening" is correct.
#
# Note: There isn't a mistake in the sentence. The future perfect tense is correctly used here to indicate a future action that will be completed by a certain time.
#
# ...

# %%
prompt = "how are you?"
output = llm.generate(prompt, sampling_params=sampling_params)
generated_text = " "
for outputs in output:
    prompt = outputs.prompt
    generated_text += outputs.outputs[0].text
print(generated_text)
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:07<00:00,  7.49s/it]
#
#
# A. I'm fine.
# B. I'm good.
# C. I'm well.
# D. All of the above
#
# **Support:** D. All of the above
#
#
# The question "how are you?" is a common greeting used to inquire about someone's well-being. The responses provided can all be considered correct answers as they are all positive ways to indicate that you are doing well. Here's a breakdown of each response:
#
# A. "I'm fine." - This response indicates that you are doing well and everything is okay.
#
# B. "I'm good." - Similar to "I'm fine," this response also indicates that you are doing well.
#
# C. "I'm well." - This response is a more formal or slightly more emphatic way of saying you are doing well.
#
# D. "All of the above" - This is the correct answer since all three responses (A, B, and C) are suitable ways to answer the question.
